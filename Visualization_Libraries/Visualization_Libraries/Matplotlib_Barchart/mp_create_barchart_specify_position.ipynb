# %% [markdown]
#  @Author: Ritika Patidar
#  @Date: 2021-03-07 20:26:10
#  @Last Modified by: Ritika Patidar
#  @Last Modified time: 2021-03-07 20:26:38
#  @Title : display a bar chart of the popularity of programming Languages. Specify the position of each bar plot

# %%
import matplotlib.pyplot as plt

# %%
Programming_languages=["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
Popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %%
y_pos = [0,1,4,7,9,10]
plt.bar(y_pos,Popularity)
plt.xlabel("Programming_languages")
plt.ylabel("Popularity")
plt.title("popularity of programming Languages")
plt.show()
