# %% [markdown]
#  @Author: Ritika Patidar
#  @Date: 2021-03-06 23:15:10
#  @Last Modified by: Ritika Patidar
#  @Last Modified time: 2021-03-06 23:15:38
#  @Title : plot two or more lines with legends, different widths and colors

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
y_axis_values_1=np.array([0,1,2,3])
y_axis_values_2=np.array([3,4,5,6])

# %%
plt.plot(y_axis_values_1,color="b",linewidth=3,label="Line with width 3")
plt.plot(y_axis_values_2,color="g",linewidth=5,label="Line with width 5")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
plt.title("Two or more lines on same plot with suitable legends")
# Out:
# Text(0.5, 1.0, 'Two or more lines on same plot with suitable legends')

# %%
plt.show()
