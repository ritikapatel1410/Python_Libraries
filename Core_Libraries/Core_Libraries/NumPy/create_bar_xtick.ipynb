# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_value = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
y_value = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %%
plt.bar(x_axis,y_value)
plt.xticks(np.arange(len(x_value)), x_value)
plt.yticks(np.arange(0,max(y_value)+5,5))
plt.show()
